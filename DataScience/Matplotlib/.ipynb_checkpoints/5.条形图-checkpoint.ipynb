# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 5
y=[20,10,30,25,15]
index = np.arange(N)

# %%
p1 = plt.bar(index,y,width=0.5,color='red',bottom=100)

plt.show()

# %%
p3=plt.barh(index,y,height=0.5)

plt.show()

# %%
index=np.arange(4)

sales_BJ=[52,55,63,53]
sales_SH=[44,66,55,41]

bar_width=0.3

# %%
plt.bar(index,sales_BJ,bar_width,color='b')
plt.bar(index+bar_width,sales_SH,bar_width,color='r')
plt.show()

# %%
plt.bar(index,sales_BJ,bar_width,color='b')
plt.bar(index,sales_SH,bar_width,color='r',bottom=sales_BJ)
plt.show()

# %%
index=np.arange(5)

sales_BJ=[52,55,63,53,40]
sales_SH=[44,66,55,41,30]

bar_width=0.3

plt.barh(left=0,bottom=index,width=sales_BJ,height=bar_width,color='b')
plt.barh(left=0,bottom=index+bar_width,width=sales_SH,height=bar_width,color='r')
plt.show()

# plt.barh(left=0,bottom=index,width=sales_BJ,height=bar_width,color='b')
# plt.barh(left=sales_BJ,bottom=index,width=sales_SH,height=bar_width,color='r')
# plt.show()
# Out:
# d:\users\lib\site-packages\matplotlib\pyplot.py:2790: MatplotlibDeprecationWarning: The *bottom* kwarg to `barh` is deprecated use *y* instead. Support for *bottom* will be removed in Matplotlib 3.0
#   ret = ax.barh(*args, **kwargs)
